# %% [markdown]
# # Set-Up

# %% [markdown]
# Installations and imports:

# %%
import os
from math import ceil
import time
import json
import numpy as np
import sys
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import fenics_helpers

# %% [markdown]
# Plotting settings:

# %%
sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})
mpl.rcParams['figure.dpi'] = 100
mpl_save_dpi = 300

# %% [markdown]
# Save settings:

# %%
fig_save_dir = './figs'
if not os.path.isdir(fig_save_dir):
    os.mkdir(fig_save_dir)
data_save_dir = './data'
if not os.path.isdir(data_save_dir):
    os.mkdir(data_save_dir)

# %% [markdown]
# Define parameters which never change between simulations:

# %%
always_fixed_params = {# Physical parameters:
                       'density': 0.00102, # in g/mm^3
                       'g': 9.81, # in m/s^3
                       # Beam mesh/geometry parameters:
                       'width': 40, # in mm
                       'length': 90, # in mm
                       'elem_order': 2,
                       # Non-linear solver parameters:
                       'num_load_steps': 30, 
                       'rtol': 1e-9, 
                       'atol': 1e-9, 
                       'max_iter': 50}

# %% [markdown]
# # Convergence Studies

# %% [markdown]
# ## Mesh Size Convergence

# %% [markdown]
# Informal parameter search shows that greatest displacements occur at around 120 degrees - perform convergence study here.

# %%
fixed_params = {'C_1': 1.9, # in kPa
                'beam_angle': 90, # in degrees
                'kappa': 3000, # in kPa
                **always_fixed_params}

# Vary number of elements along width of beam:
NW_list = [1, 2, 3, 4, 5, 6, 7, 8]
  
results = {key: [] for key in ('end_disp', 'elem_size', 'num_elem', 'NW', 'NL', 'volume')}
for i, NW in enumerate(NW_list):
    
    # Compute vertex length of cube elements:
    elem_size = fixed_params['width']/NW
    # Compute number of elements along length of beam:
    NL = ceil(fixed_params['length']/elem_size)

    print(f"Simulating Mesh {i+1}/{len(NW_list)} (Num elem = {NL*NW*NW})")
    results['NW'].append(NW)
    results['NL'].append(NL)
    results['elem_size'].append(elem_size)
    results['num_elem'].append(NL*NW*NW)
    
    mesh = fenics_helpers.create_cuboidal_mesh(fixed_params['length'], fixed_params['width'], NL, NW) 
    u = fenics_helpers.simulate_neohookean_beam(mesh, **fixed_params)
    
    results['end_disp'].append(fenics_helpers.compute_end_displacement(u, mesh, fixed_params['width'], fixed_params['length']))
    results['volume'].append(fenics_helpers.compute_pre_and_postdeformation_volume(u, mesh))

results['fixed_params'] = fixed_params

with open(os.path.join(data_save_dir, 'neohookean_beam_meshsize_convergence.json'), 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Simulating Mesh 1/8 (Num elem = 3)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulating Mesh 2/8 (Num elem = 20)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulating Mesh 3/8 (Num elem = 63)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulating Mesh 4/8 (Num elem = 144)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulating Mesh 5/8 (Num elem = 300)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulating Mesh 6/8 (Num elem = 504)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulating Mesh 7/8 (Num elem = 784)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulating Mesh 8/8 (Num elem = 1152)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...

# %% [markdown]
# Plotting the convergence results:

# %%
with open(os.path.join(data_save_dir, 'neohookean_beam_meshsize_convergence.json'), 'r') as f:
    results = json.load(f)
# Displacement convergence:
sns.lineplot(data=results, x='num_elem', y='end_disp', marker='x', markersize=8, mec='r')
plt.xlabel('Number of Mesh Elements')
plt.ylabel('Beam Tip Deformation / mm')
plt.savefig(os.path.join(fig_save_dir, 'meshsize_convergence_disp.svg'), dpi=mpl_save_dpi)
plt.show()

# %%
# Absolute error:
max_disp = np.max(results['end_disp'])
abs_error = np.abs(results['end_disp'] - max_disp)
sns.lineplot(x=results['num_elem'], y=abs_error, marker='x', markersize=8, mec='r')
plt.xlabel('Number of Mesh Elements')
plt.ylabel('Absolute Error in Beam Tip Deformation / mm')
plt.savefig(os.path.join(fig_save_dir, 'meshsize_convergence_abs_err.svg'), dpi=mpl_save_dpi)
plt.show()

# %%
# Relative error:
pct_error = 100*abs_error/max_disp
sns.lineplot(x=results['num_elem'], y=pct_error, marker='x', markersize=8, mec='r')
plt.xlabel('Number of Mesh Elements')
plt.ylabel('Percentage Error in Beam Tip Deflection')
plt.savefig(os.path.join(fig_save_dir, 'meshsize_convergence_pct_err.svg'), dpi=mpl_save_dpi)
plt.show()

# %% [markdown]
# It appears that around 500 elements (i.e. number of elements along beam width = 6) achieves an percentage error of roughly 1% - this is more than sufficient for our purposes.

# %% [markdown]
# ## Kappa Convergence

# %%
fixed_params = {'C_1': 1.9, # in kPa
                'NW': 6, 
                'beam_angle': 90, # in degrees
                **always_fixed_params}
fixed_params['elem_size'] =  fixed_params['width']/fixed_params['NW']
fixed_params['NL'] =  ceil(fixed_params['length']/fixed_params['elem_size'])

# Mesh doesn't vary for different kappa values - create it once at the start:
mesh = fenics_helpers.create_cuboidal_mesh(*[fixed_params[key] for key in ('length', 'width', 'NL', 'NW')]) 

# Vary kappa between simulations:
kappa_list = [0, 500, 1000, 1500, 2000, 2500, 3000, 3250, 3500] # all in kPa

results = {key: [] for key in ('end_disp', 'volume', 'kappa')}
for i, kappa in enumerate(kappa_list):

    print(f"Simulating Mesh {i+1}/{len(kappa_list)} (Kappa = {kappa})")
    results['kappa'].append(kappa)

    u = fenics_helpers.simulate_neohookean_beam(mesh, kappa=kappa, **fixed_params)
    
    results['end_disp'].append(fenics_helpers.compute_end_displacement(u, mesh, fixed_params['width'], fixed_params['length']))
    results['volume'].append(fenics_helpers.compute_pre_and_postdeformation_volume(u, mesh))

results['fixed_params'] = fixed_params

with open(os.path.join(data_save_dir, 'neohookean_beam_kappa_convergence.json'), 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Simulating Mesh 1/9 (Kappa = 0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulating Mesh 2/9 (Kappa = 500)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulating Mesh 3/9 (Kappa = 1000)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulating Mesh 4/9 (Kappa = 1500)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulating Mesh 5/9 (Kappa = 2000)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulating Mesh 6/9 (Kappa = 2500)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulating Mesh 7/9 (Kappa = 3000)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulating Mesh 8/9 (Kappa = 3250)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulating Mesh 9/9 (Kappa = 3500)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...

# %% [markdown]
# Plotting the convergence results:

# %%
with open(os.path.join(data_save_dir, 'neohookean_beam_kappa_convergence.json'), 'r') as f:
    results = json.load(f)
# Volume convergence:
vols = np.array(results['volume'])
init_vol = vols[0,0]
disp_vols = vols[:,1]
sns.lineplot(x=results['kappa'], y=disp_vols, marker='x', markersize=8, mec='r')
plt.axhline(y=init_vol, color='green', linestyle='--')
plt.xlabel('$\kappa$ / kPa')
plt.ylabel('Beam Volume after Deformation / mm$^3$')
plt.savefig(os.path.join(fig_save_dir, 'kappa_convergence_vol.svg'), dpi=mpl_save_dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# Let's 'zoom in' on this plot:

# %%
sns.lineplot(x=results['kappa'][1:], y=disp_vols[1:], marker='x', markersize=8, mec='r')
plt.axhline(y=init_vol, color='green', linestyle='--')
plt.xlabel('$\kappa$ / kPa')
plt.ylabel('Beam Volume after Deformation / mm$^3$')
plt.savefig(os.path.join(fig_save_dir, 'kappa_convergence_vol_zoom.svg'), dpi=mpl_save_dpi, bbox_inches='tight')
plt.show()

# %%
# Absolute error convergence:
abs_error = np.abs(disp_vols[1:] - init_vol)
sns.lineplot(x=results['kappa'][1:], y=abs_error, marker='x', markersize=8, mec='r')
plt.xlabel('$\kappa$ / kPa')
plt.ylabel('Change in Volume / mm$^3$')
plt.savefig(os.path.join(fig_save_dir, 'kappa_convergence_abs.svg'), dpi=mpl_save_dpi, bbox_inches='tight')
plt.show()

# %%
# Percentage error convergence:
pct_error = 100*abs_error/init_vol
sns.lineplot(x=results['kappa'][1:], y=pct_error, marker='x', markersize=8, mec='r')
plt.xlabel('$\kappa$ / kPa')
plt.ylabel('Percentage Change in Volume / mm$^3$')
plt.savefig(os.path.join(fig_save_dir, 'kappa_convergence_pct.svg'), dpi=mpl_save_dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# Out of interest, let's also see to what extent $\kappa$ affects the measured beam tip displacement:

# %%
sns.lineplot(data=results, x='kappa', y='end_disp', marker='x', markersize=8, mec='r')
plt.xlabel('$\kappa$ / kPa')
plt.ylabel('Beam Tip Displacement / mm')
plt.savefig(os.path.join(fig_save_dir, 'kappa_convergence_disp.svg'), dpi=mpl_save_dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# 'Zooming in':

# %%
sns.lineplot(x=results['kappa'][1:], y=results['end_disp'][1:], marker='x', markersize=8, mec='r')
plt.xlabel('$\kappa$ / kPa')
plt.ylabel('Beam Tip Displacement / mm')
plt.savefig(os.path.join(fig_save_dir, 'kappa_convergence_disp_zoom.svg'), dpi=mpl_save_dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# It appears that $\kappa$ doesn't have a particular large effect on the measured beam tip displacement. Conseqeuently, we'll stick with our initial choice of $\kappa$ = 3000 kPa. Note that for $\kappa >$ 3500 kPa, the non-linear solver tends to run into convergence issues.

# %% [markdown]
# # Data Generation

# %% [markdown]
# Define fixed params and create mesh:

# %%
fixed_params = {'kappa': 3000, # in kPa
                'NW': 6,
                **always_fixed_params}
fixed_params['elem_size'] =  fixed_params['width']/fixed_params['NW']
fixed_params['NL'] =  ceil(fixed_params['length']/fixed_params['elem_size'])
mesh = fenics_helpers.create_cuboidal_mesh(*[fixed_params[key] for key in ('length', 'width', 'NL', 'NW')])

# %% [markdown]
# Define grid points for training data evaluations:

# %%
num_train_pts = 10 # number of training points per dimension of grid
min_C_1, max_C_1 = 1.9, 6.9 # in kPa
C_1_list = [C_1 for C_1 in np.linspace(min_C_1, max_C_1, num_train_pts)]
min_angle, max_angle = 0, 180 # in degrees
beam_angle_list = [y for y in np.linspace(min_angle, max_angle, num_train_pts)]
training_param_combos = fenics_helpers.create_param_combos(C_1=C_1_list, beam_angle=beam_angle_list)

# %% [markdown]
# Define grid points for test data evaluations:

# %%
num_test_pts = num_train_pts-1
delta_C_1 = (max_C_1-min_C_1)/num_test_pts
delta_angle = (max_angle-min_angle)/num_test_pts
C_1_list = [C_1 for C_1 in np.linspace(min_C_1+0.5*delta_C_1, max_C_1-0.5*delta_C_1, num_test_pts)]
beam_angle_list = [angle for angle in np.linspace(min_angle+0.5*delta_angle, max_angle-0.5*delta_angle, num_test_pts)]
test_param_combos = fenics_helpers.create_param_combos(C_1=C_1_list, beam_angle=beam_angle_list)

# %% [markdown]
# Compute training data:

# %%
results = {key: [] for key in ('C_1', 'beam_angle', 'end_disp', 't_solve', 'volume')}
for i, params in enumerate(training_param_combos):
    
    print(f"Simulation {i+1}/{len(training_param_combos)} (C_1 = {params['C_1']}, Beam angle = {params['beam_angle']})")
    results['C_1'].append(params['C_1'])
    results['beam_angle'].append(params['beam_angle'])

    # Note how long each simulation takes:
    t_start = time.time()
    u = fenics_helpers.simulate_neohookean_beam(mesh, C_1=params['C_1'], beam_angle=params['beam_angle'], **fixed_params)
    t_solve = time.time() - t_start
    results['t_solve'].append(t_solve)
    print(f'Simulation took {t_solve/60:.2f} mins.\n')
    
    results['end_disp'].append(fenics_helpers.compute_end_displacement(u, mesh, fixed_params['width'], fixed_params['length']))
    results['volume'].append(fenics_helpers.compute_pre_and_postdeformation_volume(u, mesh))

results['fixed_params'] = fixed_params

with open(os.path.join(data_save_dir, 'neohookean_beam_training_data.json'), 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Simulation 1/100 (C_1 = 1.9, Beam angle = 0.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.43 mins.
#
# Simulation 2/100 (C_1 = 1.9, Beam angle = 20.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.90 mins.
#
# Simulation 3/100 (C_1 = 1.9, Beam angle = 40.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.66 mins.
#
# Simulation 4/100 (C_1 = 1.9, Beam angle = 60.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.85 mins.
#
# Simulation 5/100 (C_1 = 1.9, Beam angle = 80.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.30 mins.
#
# Simulation 6/100 (C_1 = 1.9, Beam angle = 100.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.11 mins.
#
# Simulation 7/100 (C_1 = 1.9, Beam angle = 120.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.93 mins.
#
# Simulation 8/100 (C_1 = 1.9, Beam angle = 140.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.49 mins.
#
# Simulation 9/100 (C_1 = 1.9, Beam angle = 160.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.41 mins.
#
# Simulation 10/100 (C_1 = 1.9, Beam angle = 180.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.02 mins.
#
# Simulation 11/100 (C_1 = 2.4555555555555557, Beam angle = 0.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.83 mins.
#
# Simulation 12/100 (C_1 = 2.4555555555555557, Beam angle = 20.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.05 mins.
#
# Simulation 13/100 (C_1 = 2.4555555555555557, Beam angle = 40.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.17 mins.
#
# Simulation 14/100 (C_1 = 2.4555555555555557, Beam angle = 60.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.69 mins.
#
# Simulation 15/100 (C_1 = 2.4555555555555557, Beam angle = 80.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.21 mins.
#
# Simulation 16/100 (C_1 = 2.4555555555555557, Beam angle = 100.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.07 mins.
#
# Simulation 17/100 (C_1 = 2.4555555555555557, Beam angle = 120.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.17 mins.
#
# Simulation 18/100 (C_1 = 2.4555555555555557, Beam angle = 140.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.32 mins.
#
# Simulation 19/100 (C_1 = 2.4555555555555557, Beam angle = 160.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.90 mins.
#
# Simulation 20/100 (C_1 = 2.4555555555555557, Beam angle = 180.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.11 mins.
#
# Simulation 21/100 (C_1 = 3.011111111111111, Beam angle = 0.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.09 mins.
#
# Simulation 22/100 (C_1 = 3.011111111111111, Beam angle = 20.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.67 mins.
#
# Simulation 23/100 (C_1 = 3.011111111111111, Beam angle = 40.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.19 mins.
#
# Simulation 24/100 (C_1 = 3.011111111111111, Beam angle = 60.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.92 mins.
#
# Simulation 25/100 (C_1 = 3.011111111111111, Beam angle = 80.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.57 mins.
#
# Simulation 26/100 (C_1 = 3.011111111111111, Beam angle = 100.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.86 mins.
#
# Simulation 27/100 (C_1 = 3.011111111111111, Beam angle = 120.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.00 mins.
#
# Simulation 28/100 (C_1 = 3.011111111111111, Beam angle = 140.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.04 mins.
#
# Simulation 29/100 (C_1 = 3.011111111111111, Beam angle = 160.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.85 mins.
#
# Simulation 30/100 (C_1 = 3.011111111111111, Beam angle = 180.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.13 mins.
#
# Simulation 31/100 (C_1 = 3.5666666666666664, Beam angle = 0.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.11 mins.
#
# Simulation 32/100 (C_1 = 3.5666666666666664, Beam angle = 20.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.36 mins.
#
# Simulation 33/100 (C_1 = 3.5666666666666664, Beam angle = 40.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.15 mins.
#
# Simulation 34/100 (C_1 = 3.5666666666666664, Beam angle = 60.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.12 mins.
#
# Simulation 35/100 (C_1 = 3.5666666666666664, Beam angle = 80.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.09 mins.
#
# Simulation 36/100 (C_1 = 3.5666666666666664, Beam angle = 100.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.10 mins.
#
# Simulation 37/100 (C_1 = 3.5666666666666664, Beam angle = 120.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.13 mins.
#
# Simulation 38/100 (C_1 = 3.5666666666666664, Beam angle = 140.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.53 mins.
#
# Simulation 39/100 (C_1 = 3.5666666666666664, Beam angle = 160.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.08 mins.
#
# Simulation 40/100 (C_1 = 3.5666666666666664, Beam angle = 180.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.25 mins.
#
# Simulation 41/100 (C_1 = 4.122222222222222, Beam angle = 0.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.79 mins.
#
# Simulation 42/100 (C_1 = 4.122222222222222, Beam angle = 20.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.29 mins.
#
# Simulation 43/100 (C_1 = 4.122222222222222, Beam angle = 40.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.09 mins.
#
# Simulation 44/100 (C_1 = 4.122222222222222, Beam angle = 60.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.21 mins.
#
# Simulation 45/100 (C_1 = 4.122222222222222, Beam angle = 80.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.16 mins.
#
# Simulation 46/100 (C_1 = 4.122222222222222, Beam angle = 100.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.25 mins.
#
# Simulation 47/100 (C_1 = 4.122222222222222, Beam angle = 120.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.02 mins.
#
# Simulation 48/100 (C_1 = 4.122222222222222, Beam angle = 140.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.95 mins.
#
# Simulation 49/100 (C_1 = 4.122222222222222, Beam angle = 160.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# ...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.13 mins.
#
# Simulation 86/100 (C_1 = 6.344444444444445, Beam angle = 100.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.07 mins.
#
# Simulation 87/100 (C_1 = 6.344444444444445, Beam angle = 120.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.30 mins.
#
# Simulation 88/100 (C_1 = 6.344444444444445, Beam angle = 140.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.73 mins.
#
# Simulation 89/100 (C_1 = 6.344444444444445, Beam angle = 160.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.49 mins.
#
# Simulation 90/100 (C_1 = 6.344444444444445, Beam angle = 180.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.36 mins.
#
# Simulation 91/100 (C_1 = 6.9, Beam angle = 0.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.38 mins.
#
# Simulation 92/100 (C_1 = 6.9, Beam angle = 20.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.53 mins.
#
# Simulation 93/100 (C_1 = 6.9, Beam angle = 40.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.53 mins.
#
# Simulation 94/100 (C_1 = 6.9, Beam angle = 60.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.45 mins.
#
# Simulation 95/100 (C_1 = 6.9, Beam angle = 80.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.47 mins.
#
# Simulation 96/100 (C_1 = 6.9, Beam angle = 100.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.69 mins.
#
# Simulation 97/100 (C_1 = 6.9, Beam angle = 120.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.57 mins.
#
# Simulation 98/100 (C_1 = 6.9, Beam angle = 140.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.57 mins.
#
# Simulation 99/100 (C_1 = 6.9, Beam angle = 160.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.57 mins.
#
# Simulation 100/100 (C_1 = 6.9, Beam angle = 180.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.19 mins.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [91], in <cell line: 20>()
#      18 results['fixed_params'] = fixed_params
#      20 with open(os.path.join(data_save_dir, 'neohookean_beam_training_data.json'), 'w'):
# ---> 21     json.dump(results, f, indent=4)
#
# File /usr/lib/python3.9/json/__init__.py:180, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
#     179 for chunk in iterable:
# --> 180     fp.write(chunk)
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# Compute test data:

# %%
results = {key: [] for key in ('C_1', 'beam_angle', 'end_disp', 't_solve', 'volume')}
for i, params in enumerate(test_param_combos):
    
    print(f"Simulation {i+1}/{len(test_param_combos)} (C_1 = {params['C_1']}, Beam angle = {params['beam_angle']})")
    results['C_1'].append(params['C_1'])
    results['beam_angle'].append(params['beam_angle'])

    # Note how long each simulation takes:
    t_start = time.time()
    u = fenics_helpers.simulate_neohookean_beam(mesh, C_1=params['C_1'], beam_angle=params['beam_angle'], **fixed_params)
    t_solve = time.time() - t_start
    results['t_solve'].append(t_solve)
    print(f'Simulation took {t_solve/60:.2f} mins.\n')
    
    results['end_disp'].append(fenics_helpers.compute_end_displacement(u, mesh, fixed_params['width'], fixed_params['length']))
    results['volume'].append(fenics_helpers.compute_pre_and_postdeformation_volume(u, mesh))
    
results['fixed_params'] = fixed_params

with open(os.path.join(data_save_dir, 'neohookean_beam_test_data.json'), 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Simulation 1/81 (C_1 = 2.1777777777777776, Beam angle = 10.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.57 mins.
#
# Simulation 2/81 (C_1 = 2.1777777777777776, Beam angle = 30.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.94 mins.
#
# Simulation 3/81 (C_1 = 2.1777777777777776, Beam angle = 50.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.64 mins.
#
# Simulation 4/81 (C_1 = 2.1777777777777776, Beam angle = 70.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.60 mins.
#
# Simulation 5/81 (C_1 = 2.1777777777777776, Beam angle = 90.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.90 mins.
#
# Simulation 6/81 (C_1 = 2.1777777777777776, Beam angle = 110.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.81 mins.
#
# Simulation 7/81 (C_1 = 2.1777777777777776, Beam angle = 130.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.17 mins.
#
# Simulation 8/81 (C_1 = 2.1777777777777776, Beam angle = 150.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.93 mins.
#
# Simulation 9/81 (C_1 = 2.1777777777777776, Beam angle = 170.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.83 mins.
#
# Simulation 10/81 (C_1 = 2.7333333333333334, Beam angle = 10.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.15 mins.
#
# Simulation 11/81 (C_1 = 2.7333333333333334, Beam angle = 30.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.77 mins.
#
# Simulation 12/81 (C_1 = 2.7333333333333334, Beam angle = 50.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.92 mins.
#
# Simulation 13/81 (C_1 = 2.7333333333333334, Beam angle = 70.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.79 mins.
#
# Simulation 14/81 (C_1 = 2.7333333333333334, Beam angle = 90.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.08 mins.
#
# Simulation 15/81 (C_1 = 2.7333333333333334, Beam angle = 110.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.04 mins.
#
# Simulation 16/81 (C_1 = 2.7333333333333334, Beam angle = 130.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.29 mins.
#
# Simulation 17/81 (C_1 = 2.7333333333333334, Beam angle = 150.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.97 mins.
#
# Simulation 18/81 (C_1 = 2.7333333333333334, Beam angle = 170.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.86 mins.
#
# Simulation 19/81 (C_1 = 3.2888888888888888, Beam angle = 10.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.89 mins.
#
# Simulation 20/81 (C_1 = 3.2888888888888888, Beam angle = 30.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.55 mins.
#
# Simulation 21/81 (C_1 = 3.2888888888888888, Beam angle = 50.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.61 mins.
#
# Simulation 22/81 (C_1 = 3.2888888888888888, Beam angle = 70.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.56 mins.
#
# Simulation 23/81 (C_1 = 3.2888888888888888, Beam angle = 90.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.65 mins.
#
# Simulation 24/81 (C_1 = 3.2888888888888888, Beam angle = 110.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.65 mins.
#
# Simulation 25/81 (C_1 = 3.2888888888888888, Beam angle = 130.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.52 mins.
#
# Simulation 26/81 (C_1 = 3.2888888888888888, Beam angle = 150.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.47 mins.
#
# Simulation 27/81 (C_1 = 3.2888888888888888, Beam angle = 170.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.48 mins.
#
# Simulation 28/81 (C_1 = 3.844444444444444, Beam angle = 10.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.61 mins.
#
# Simulation 29/81 (C_1 = 3.844444444444444, Beam angle = 30.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.77 mins.
#
# Simulation 30/81 (C_1 = 3.844444444444444, Beam angle = 50.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.85 mins.
#
# Simulation 31/81 (C_1 = 3.844444444444444, Beam angle = 70.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.55 mins.
#
# Simulation 32/81 (C_1 = 3.844444444444444, Beam angle = 90.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.79 mins.
#
# Simulation 33/81 (C_1 = 3.844444444444444, Beam angle = 110.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.69 mins.
#
# Simulation 34/81 (C_1 = 3.844444444444444, Beam angle = 130.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.57 mins.
#
# Simulation 35/81 (C_1 = 3.844444444444444, Beam angle = 150.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.52 mins.
#
# Simulation 36/81 (C_1 = 3.844444444444444, Beam angle = 170.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.56 mins.
#
# Simulation 37/81 (C_1 = 4.4, Beam angle = 10.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.72 mins.
#
# Simulation 38/81 (C_1 = 4.4, Beam angle = 30.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.88 mins.
#
# Simulation 39/81 (C_1 = 4.4, Beam angle = 50.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.84 mins.
#
# Simulation 40/81 (C_1 = 4.4, Beam angle = 70.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.88 mins.
#
# Simulation 41/81 (C_1 = 4.4, Beam angle = 90.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.71 mins.
#
# Simulation 42/81 (C_1 = 4.4, Beam angle = 110.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.60 mins.
#
# Simulation 43/81 (C_1 = 4.4, Beam angle = 130.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.61 mins.
#
# Simulation 44/81 (C_1 = 4.4, Beam angle = 150.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.57 mins.
#
# Simulation 45/81 (C_1 = 4.4, Beam angle = 170.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.51 mins.
#
# Simulation 46/81 (C_1 = 4.955555555555556, Beam angle = 10.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.60 mins.
#
# Simulation 47/81 (C_1 = 4.955555555555556, Beam angle = 30.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.95 mins.
#
# Simulation 48/81 (C_1 = 4.955555555555556, Beam angle = 50.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.86 mins.
#
# Simulation 49/81 (C_1 = 4.955555555555556, Beam angle = 70.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 2.03 mins.
#
# ...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.87 mins.
#
# Simulation 66/81 (C_1 = 6.066666666666666, Beam angle = 50.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.83 mins.
#
# Simulation 67/81 (C_1 = 6.066666666666666, Beam angle = 70.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.85 mins.
#
# Simulation 68/81 (C_1 = 6.066666666666666, Beam angle = 90.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.67 mins.
#
# Simulation 69/81 (C_1 = 6.066666666666666, Beam angle = 110.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.78 mins.
#
# Simulation 70/81 (C_1 = 6.066666666666666, Beam angle = 130.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.70 mins.
#
# Simulation 71/81 (C_1 = 6.066666666666666, Beam angle = 150.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.42 mins.
#
# Simulation 72/81 (C_1 = 6.066666666666666, Beam angle = 170.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.50 mins.
#
# Simulation 73/81 (C_1 = 6.622222222222223, Beam angle = 10.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.40 mins.
#
# Simulation 74/81 (C_1 = 6.622222222222223, Beam angle = 30.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.71 mins.
#
# Simulation 75/81 (C_1 = 6.622222222222223, Beam angle = 50.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.74 mins.
#
# Simulation 76/81 (C_1 = 6.622222222222223, Beam angle = 70.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.67 mins.
#
# Simulation 77/81 (C_1 = 6.622222222222223, Beam angle = 90.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.63 mins.
#
# Simulation 78/81 (C_1 = 6.622222222222223, Beam angle = 110.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.59 mins.
#
# Simulation 79/81 (C_1 = 6.622222222222223, Beam angle = 130.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.72 mins.
#
# Simulation 80/81 (C_1 = 6.622222222222223, Beam angle = 150.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.63 mins.
#
# Simulation 81/81 (C_1 = 6.622222222222223, Beam angle = 170.0)
# Performing load step 1/30...
# Performing load step 2/30...
# Performing load step 3/30...
# Performing load step 4/30...
# Performing load step 5/30...
# Performing load step 6/30...
# Performing load step 7/30...
# Performing load step 8/30...
# Performing load step 9/30...
# Performing load step 10/30...
# Performing load step 11/30...
# Performing load step 12/30...
# Performing load step 13/30...
# Performing load step 14/30...
# Performing load step 15/30...
# Performing load step 16/30...
# Performing load step 17/30...
# Performing load step 18/30...
# Performing load step 19/30...
# Performing load step 20/30...
# Performing load step 21/30...
# Performing load step 22/30...
# Performing load step 23/30...
# Performing load step 24/30...
# Performing load step 25/30...
# Performing load step 26/30...
# Performing load step 27/30...
# Performing load step 28/30...
# Performing load step 29/30...
# Performing load step 30/30...
# Simulation took 1.63 mins.
